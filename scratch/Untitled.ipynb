# %% [markdown]
# # Text
# Text

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Part 1

# %%
x = np.arange(0,20,.1)
y = np.sin(x)
plt.plot (x,y)

# %% [markdown]
# # Part 2
# Test

# %%
x = np.arange(0,20,.1)
y = np.cos(x)
plt.plot (x,y)
